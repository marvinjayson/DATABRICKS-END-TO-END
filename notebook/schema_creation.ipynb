# %%
# %sql
-- Create schemas under the 'sales' catalog
CREATE DATABASE IF NOT EXISTS sales.silver;
CREATE DATABASE IF NOT EXISTS sales.gold;
CREATE DATABASE IF NOT EXISTS sales.dq;
CREATE DATABASE IF NOT EXISTS sales.audit;
CREATE DATABASE IF NOT EXISTS sales.bronze;
CREATE DATABASE IF NOT EXISTS sales.mapping;

-- Drop the table sales.default.customers
DROP TABLE IF EXISTS sales.default.customers;

-- Drop the old mappings volume under sales.bronze
DROP VOLUME IF EXISTS sales.bronze.mappings;

-- List schemas under the 'sales' catalog to verify
SHOW SCHEMAS IN sales
