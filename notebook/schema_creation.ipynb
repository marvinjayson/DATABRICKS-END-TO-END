# %%
# Create schemas 'silver' and 'gold' under the 'sales' catalog
spark.sql("CREATE DATABASE IF NOT EXISTS sales.silver")
spark.sql("CREATE DATABASE IF NOT EXISTS sales.gold")
spark.sql("CREATE DATABASE IF NOT EXISTS sales.dq")
spark.sql("CREATE DATABASE IF NOT EXISTS sales.audit")
spark.sql("CREATE DATABASE IF NOT EXISTS sales.bronze")

# List schemas under the 'sales' catalog to verify
display(spark.sql("SHOW SCHEMAS IN sales"))
